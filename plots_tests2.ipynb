# %% [markdown]
# Second try for getting the plots nice and fitted

# %%
import pandas as pd 
import math 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df_LG_lake=pd.read_excel('Lab_tests_results.xlsx', sheet_name='LG_lake')

df_LG_spring=pd.read_excel('Lab_tests_results.xlsx', sheet_name='LG_spring')

df_S3=pd.read_excel('Lab_tests_results.xlsx', sheet_name='S3')

df_S4=pd.read_excel('Lab_tests_results.xlsx', sheet_name='S4')

# %%
def mean_of_repeats(df, title1='Fine', title2='Medium', title3='Coarse'): 

    'dataframe input'
    'columns for which you want to summarise'

    titles=np.array([title1,title2,title3])

    for i in titles:
        I=f'{i}_R1'
        II=f'{i}_R2'
        III=f'{i}_R3'

        df[f'{i}_mean']=df[[I,II,III]].mean(axis=1)


    return df

# %%
mean_of_repeats(df_LG_lake, title1='Fine', title2='Medium', title3='Coarse')
mean_of_repeats(df_LG_spring, title1='Fine', title2='Medium', title3='Coarse')
mean_of_repeats(df_S3, title1='Fine', title2='Medium', title3='Coarse')
mean_of_repeats(df_S4, title1='Fine', title2='Medium', title3='Coarse')
# Out:
#     Time_(min)  Fine_R1  Fine_R2  Fine_R3  Medium_R1  Medium_R2  Medium_R3  \
# 0          0.0     2.61     2.65     2.65       2.61       2.65       2.65
# 1          0.5     4.37     4.20     4.12       4.33       3.57       3.95
# 2          1.0     5.31     4.81     4.56       5.35       4.34       4.56
# 3          1.5     5.71     5.10     4.92       5.66       4.75       4.91
# 4          2.0     5.90     5.47     5.25       5.87       5.08       5.14
# 5          2.5     6.08     5.71     5.45       6.04       5.33       5.34
# 6          3.0     6.21     5.83     5.62       6.12       5.54       5.54
# 7          3.5     6.29     5.96     5.79       6.21       5.68       5.71
# 8          4.0     6.37     6.08     5.91       6.29       5.83       5.80
# 9          4.5     6.46     6.16     6.00       6.37       5.92       5.91
# 10         5.0     6.50     6.25     6.12       6.42       6.00       6.00
# 11         5.5     6.55     6.29     6.21       6.46       6.08       6.08
# 12         6.0     6.59     6.37     6.25       6.50       6.16       6.12
# 13         6.5     6.63     6.42     6.33       6.54       6.21       6.17
# 14         7.0     6.70     6.46     6.37       6.58       6.26       6.25
# 15         7.5     6.71     6.50     6.42       6.63       6.33       6.29
# 16         8.0     6.75     6.54     6.46       6.67       6.37       6.33
# 17         8.5     6.76     6.58     6.50       6.71       6.42       6.37
# 18         9.0     6.79     6.62     6.54       6.74       6.46       6.42
# 19         9.5     6.83     6.63     6.55       6.76       6.50       6.46
# 20        10.0     6.84     6.67     6.58       6.78       6.50       6.49
#
#     Coarse_R1  Coarse_R2  Coarse_R3  Fine_mean  Medium_mean  Coarse_mean
# 0        2.61       2.65       2.65   2.636667     2.636667     2.636667
# 1        4.03       2.91       3.32   4.230000     3.950000     3.420000
# 2        4.91       4.45       4.07   4.893333     4.750000     4.476667
# 3        5.40       4.69       4.41   5.243333     5.106667     4.833333
# 4        5.62       4.95       4.66   5.540000     5.363333     5.076667
# 5        5.90       5.17       4.87   5.746667     5.570000     5.313333
# 6        5.96       5.35       5.08   5.886667     5.733333     5.463333
# 7        6.08       5.50       5.25   6.013333     5.866667     5.610000
# 8        6.16       5.62       5.41   6.120000     5.973333     5.730000
# 9        6.25       5.74       5.54   6.206667     6.066667     5.843333
# 10       6.33       5.83       5.66   6.290000     6.140000     5.940000
# 11       6.37       5.87       5.75   6.350000     6.206667     5.996667
# 12       6.46       5.96       5.83   6.403333     6.260000     6.083333
# 13       6.50       6.01       5.92   6.460000     6.306667     6.143333
# 14       6.54       6.08       6.00   6.510000     6.363333     6.206667
# 15       6.58       6.12       6.08   6.543333     6.416667     6.260000
# 16       6.62       6.17       6.12   6.583333     6.456667     6.303333
# 17       6.67       6.22       6.21   6.613333     6.500000     6.366667
# 18       6.69       6.28       6.25   6.650000     6.540000     6.406667
# 19       6.71       6.32       6.29   6.670000     6.573333     6.440000
# 20       6.75       6.37       6.33   6.696667     6.590000     6.483333

# %%
def plot_repeats_mean_loc_size(df, size='Fine', loc='LG lake'):
    """goal; plot all repeat measurements and fit a model to it and to the mean"""

    plt.figure(figsize=[16,10])
    plt.scatter(df['Time_(min)'], df[f'{size}_R1'], color='k', s=25, marker='x', label="Repeat 1")
    plt.scatter(df['Time_(min)'], df[f'{size}_R2'], color='k', s=25, marker='o', label="Repeat 2")
    plt.scatter(df['Time_(min)'], df[f'{size}_R3'], color='k', s=25, marker='d', label="Repeat 3")
    plt.scatter(df['Time_(min)'], df[f'{size}_mean'], color='r', s=25, label="Mean")

    plt.axhline(3, color='m', linestyle='--', label='Expected Fe barrier')
    plt.axhline(7, color='grey', linestyle='--', label='neutral pH')

    plt.xlabel('Time (minutes)')
    plt.ylabel('pH')
    plt.legend(loc='center right', bbox_to_anchor=(1.1,0.1))
    plt.grid()
    plt.savefig(f'images_new/{loc} at measurements and mean for grainsize {size}.png', bbox_inches='tight', dpi=300)

# %%
plot_repeats_mean_loc_size(df_LG_lake, size='Fine', loc='LG lake')
plot_repeats_mean_loc_size(df_LG_lake, size='Medium', loc='LG lake')
plot_repeats_mean_loc_size(df_LG_lake, size='Coarse', loc='LG lake')

# %%
plot_repeats_mean_loc_size(df_LG_spring, size='Fine', loc='LG spring')
plot_repeats_mean_loc_size(df_LG_spring, size='Medium', loc='LG spring')
plot_repeats_mean_loc_size(df_LG_spring, size='Coarse', loc='LG spring')

# %%
plot_repeats_mean_loc_size(df_S3, size='Fine', loc='Covica S3')
plot_repeats_mean_loc_size(df_S3, size='Medium', loc='Covica S3')
plot_repeats_mean_loc_size(df_S3, size='Coarse', loc='Covica S3')

# %%
plot_repeats_mean_loc_size(df_S4, size='Fine', loc='Covica S4')
plot_repeats_mean_loc_size(df_S4, size='Medium', loc='Covica S4')
plot_repeats_mean_loc_size(df_S4, size='Coarse', loc='Covica S4')

# %%
def spherical_model():

# %%
def plot_repeats_mean_loc_size_model_fit(df, size='Fine', loc='LG lake'):
    """goal; plot all repeat measurements and fit a model to it and to the mean"""

    plt.figure(figsize=[16,10])
    plt.scatter(df['Time_(min)'], df[f'{size}_R1'], color='k', s=25, marker='x', label="Repeat 1")
    plt.scatter(df['Time_(min)'], df[f'{size}_R2'], color='k', s=25, marker='o', label="Repeat 2")
    plt.scatter(df['Time_(min)'], df[f'{size}_R3'], color='k', s=25, marker='d', label="Repeat 3")
    plt.scatter(df['Time_(min)'], df[f'{size}_mean'], color='r', s=25, label="Mean")

    plt.axhline(3, color='m', linestyle='--', label='Expected Fe barrier')
    plt.axhline(7, color='grey', linestyle='--', label='neutral pH')

    plt.xlabel('Time (minutes)')
    plt.ylabel('pH')
    plt.legend(loc='center right', bbox_to_anchor=(1.1,0.1))
    plt.grid()
    plt.savefig(f'images_new/{loc} modelfit grainsize {size}.png', bbox_inches='tight', dpi=300)
